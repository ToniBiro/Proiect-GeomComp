# %%
import GCplot
firstFig  = [(0, 0), (3,0), (3,3), (0,3), (0,0), (1,1), (1,2), (2,2), (2,1), (1,1)]
secondFig = [(-1,1.2), (-1,1.8), (4,1.8), (4,1.2)]
interFig  = [[(0,1.2), (0,1.8), (1,1.8), (1,1.2)], [(2,1.2), (2,1.8), (3,1.8), (3,1.2)], [(0,1), (0,2)], [(1,0), (3,0)], [(0,0)]]
firstFigColor  = "blue"
secondFigColor = "red"
interFigColor  = "yellow"

# %%
GCplot.draw (firstFig, secondFig, interFig, firstFigColor, secondFigColor,interFigColor)

# %%
import test
